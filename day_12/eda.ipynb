# %% [markdown]
# # EDA (Exploratory Data Analysis) in Python
# written by: Ejaz ur Rehman\
# date: 2025-01-30\
# email: ijazfinance@gmail.com

# %% [markdown]
# ##### Exploratory Data Analysis (EDA) is a critical step in the data science workflow. It involves analyzing and summarizing datasets to understand their main characteristics, often using visual methods and statistical techniques. The primary goal of EDA is to uncover patterns, spot anomalies, test hypotheses, and check assumptions with the help of summary statistics and graphical representations.

# %%
# importing liabraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Import the dataset

# %%
# importing the data
df = sns.load_dataset ('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### 2. Check the data insight

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.describe ()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head ()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.nunique ()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %% [markdown]
# ### 3. Finding Missing Values

# %%
df.isnull().sum ()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Calculate missing value percentage
missing_percentage = round((df.isnull().sum() / len(df)) * 100, 2)
# Display missing value percentages
print(missing_percentage)
# Visualize missing value percentages
missing_percentage.plot(kind='bar', figsize=(8, 6), color='blue')
plt.title('Missing Value Percentage in Titanic Dataset')
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.xticks(rotation=45)
plt.show()
# Out:
# survived        0.00
# pclass          0.00
# sex             0.00
# age            19.87
# sibsp           0.00
# parch           0.00
# fare            0.00
# embarked        0.22
# class           0.00
# who             0.00
# adult_male      0.00
# deck           77.22
# embark_town     0.22
# alive           0.00
# alone           0.00
# dtype: float64

# %%
# Create a heatmap for missing values
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=True, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### 4. Handling Missing Values

# %% [markdown]
# ##### 4.1 Age Column (Numeric Data)

# %%
# Fill missing values in 'Age' with the median
df['age'].fillna(df['age'].median(), inplace=True)

# Verify
print(df['age'].isnull().sum())  # Should output 0
# Out:
# 0
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\1794695215.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %% [markdown]
# ##### 4.2 Embarked Column (Categorical Data)

# %%
# Fill missing values in 'Embarked' with the mode
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# Verify
print(df['embarked'].isnull().sum())  # Should output 0
# Out:
# 0
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\3074649823.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %% [markdown]
# ##### 4.3 Embarked Town Column (Categorical Data)

# %%
# Fill missing values in 'Embarked' with the mode
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# Verify
print(df['embark_town'].isnull().sum())  # Should output 0
# Out:
# 0
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\2918571484.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# %% [markdown]
# ##### 4.4 Deck Column (Categorical Data)

# %%
# Drop the 'deck' column
df.drop('deck', axis=1, inplace=True)

# Verify
print('deck' in df.columns)  # Should output False
# Out:
# False

# %%
# Check for missing values again
print(df.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# Plot the distribution of 'Age' before and after filling missing values
plt.figure(figsize=(12, 6))

# Before handling missing values
plt.subplot(1, 2, 1)
sns.histplot(df['age'].dropna(), kde=True, color='blue')
plt.title('Age Distribution (Before Imputation)')

# After handling missing values
plt.subplot(1, 2, 2)
sns.histplot(df['age'], kde=True, color='green')
plt.title('Age Distribution (After Imputation)')

plt.show()

# %%
# Save the cleaned dataset to a new CSV file
df.to_csv('titanic_cleaned.csv', index=False)

# %% [markdown]
# ### 5. Data Visualization

# %% [markdown]
# #### 5.1 Hist Plot

# %%
df['age'].hist (bins=30, color= 'darkred', alpha=0.75, figsize=(8, 6))
# alpha =0.5 makes the histogram semi-transparent, so you can see the underlying data points, it is use for opacity of the data
# Out:
# <Axes: >

# %% [markdown]
# #### 5.2 Box Plot

# %%
plt.figure(figsize=(8,6))
plt.boxplot([df['age'], df['fare']], labels=['Age', 'Fare'])
plt.title('Box Plot of Age and Fare (Titanic Dataset)')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\2360566094.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['age'], df['fare']], labels=['Age', 'Fare'])

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df)
plt.title('Box Plot of Age and Fare (Titanic Dataset)')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# #### 5.3 Boxen Plot

# %%
sns.boxenplot (data=df, y='age', x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %% [markdown]
# #### 5.4 Bar Plot

# %%
sns.barplot (x="survived", y='fare', hue="who", data=df)
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.boxplot (x="survived", y='age', hue= "who", data=df)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %% [markdown]
# #### 5.5 Calculate Quartiles for the Data

# %%
# Calculate quartiles for the 'Age' column
quartiles = df['age'].quantile([0.25, 0.5, 0.75])
print("Quartiles for Age:")
print(quartiles)

# Create a boxplot for the 'Age' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['age'], color='lightblue')
plt.title('Boxplot of Age (Quartiles) on Titanic Dataset', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Quartiles for Age:
# 0.25    22.0
# 0.50    28.0
# 0.75    35.0
# Name: age, dtype: float64

# %% [markdown]
# #### 5.6 Calculate Outliers via IQR Method

# %%
# To calculate outliers in the Titanic dataset using Python, we can use the Interquartile Range (IQR) method. 
# Outliers are typically defined as data points that fall below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR, where:

# Q1 is the first quartile (25th percentile),

# Q3 is the third quartile (75th percentile),

# IQR is the interquartile range (Q3 - Q1).
# Calculate Q1, Q3, and IQR for the 'age' column
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers in the 'age' column
outliers = df[(df['age'] < lower_bound) | (df['age'] > upper_bound)]

# Print results
print(f"Q1 (25th percentile): {Q1}")
print(f"Q3 (75th percentile): {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound for Outliers: {lower_bound}")
print(f"Upper Bound for Outliers: {upper_bound}")
print("\nOutliers in the 'age' column:")
print(outliers[['age']])

# Visualize outliers using a boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['age'], color='lightblue')
plt.title('Boxplot of Age with Outliers', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.show()
# Out:
# Q1 (25th percentile): 22.0
# Q3 (75th percentile): 35.0
# IQR: 13.0
# Lower Bound for Outliers: 2.5
# Upper Bound for Outliers: 54.5
#
# Outliers in the 'age' column:
#        age
# 7     2.00
# 11   58.00
# 15   55.00
# 16    2.00
# 33   66.00
# ..     ...
# 827   1.00
# 829  62.00
# 831   0.83
# 851  74.00
# 879  56.00
#
# [66 rows x 1 columns]

# %% [markdown]
# #### 5.7 Scatter Plot

# %%
sns.scatterplot (x="age", y="fare", data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# #### 5.8 Remove Outliers from the Data

# %%
# Remove Outliers from the data

# Calculate Q1, Q3, and IQR for the 'age' column
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from the 'age' column
df_cleaned = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

# Print results
print(f"Q1 (25th percentile): {Q1}")
print(f"Q3 (75th percentile): {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound for Outliers: {lower_bound}")
print(f"Upper Bound for Outliers: {upper_bound}")
print(f"\nOriginal dataset shape: {df.shape}")
print(f"Cleaned dataset shape: {df_cleaned.shape}")

# Visualize the cleaned data
plt.figure(figsize=(8, 6))
sns.boxplot(x=df_cleaned['age'], color='lightblue')
plt.title('Boxplot of Age (Outliers Removed)', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.show()
# Out:
# Q1 (25th percentile): 22.0
# Q3 (75th percentile): 35.0
# IQR: 13.0
# Lower Bound for Outliers: 2.5
# Upper Bound for Outliers: 54.5
#
# Original dataset shape: (891, 14)
# Cleaned dataset shape: (825, 14)

# %%
sns.scatterplot (x="age", y="fare", data=df_cleaned)
plt.ylim (0, 300)
# Out:
# (0.0, 300.0)

# %% [markdown]
# #### 5.9 Pair Plot

# %%
sns.pairplot (df, hue='survived')

# %% [markdown]
# ##### 5.9a Pair Plot with Variables

# %%
sns.pairplot (df, hue='survived', vars=['age', 'fare', 'pclass'])

# %% [markdown]
# #### 5.10 Stacked Bar Plot

# %%
# Stacked Bar Plot of Survival by Class

# Calculate survival counts per class
survival_counts = df.groupby(['class', 'survived']).size().unstack()
survival_counts.columns = ['Not Survived', 'Survived']  # Rename columns
# Plot
survival_counts.plot(kind='bar', stacked=True, color=['#ff7f0e', '#1f77b4'], figsize=(8, 6))
plt.title('Survival by Passenger Class', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Survival Status')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\2246190036.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_counts = df.groupby(['class', 'survived']).size().unstack()

# %%
# Stacked Bar Plot of Survival by Class and Gender

# Calculate survival counts by class and gender
survival_gender_counts = df.groupby(['class', 'sex', 'survived']).size().unstack([1, 2])
survival_gender_counts.columns = ['Female Not Survived', 'Female Survived', 'Male Not Survived', 'Male Survived']

# Reorder columns for logical stacking
survival_gender_counts = survival_gender_counts[['Male Not Survived', 'Male Survived', 'Female Not Survived', 'Female Survived']]
# Define colors for each segment
colors = ['#d62728', '#2ca02c', '#ff7f0e', '#1f77b4']

# Plot
ax = survival_gender_counts.plot(kind='bar', stacked=True, color=colors, figsize=(8, 6))
plt.title('Survival by Class and Gender', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\3019727697.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_gender_counts = df.groupby(['class', 'sex', 'survived']).size().unstack([1, 2])

# %% [markdown]
# #### 5.11 Swarm Plot

# %%
# Swarm Plot of Age Distribution by Class and Survival

plt.figure(figsize=(8, 6))
sns.swarmplot(
    x='class',       # Categorical variable on the x-axis (e.g., passenger class)
    y='age',         # Numerical variable on the y-axis (e.g., age)
    hue='survived',  # Split points by survival status
    data=df,
    palette={0: 'red', 1: 'green'},  # Customize colors for "Not Survived" (0) and "Survived" (1)
    dodge=True       # Separate points for each hue category
)

plt.title('Age Distribution by Passenger Class and Survival', fontsize=16)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 26.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Swarm Plot of Fare Distribution by Embarkation Port

plt.figure(figsize=(8, 6))
sns.swarmplot(
    x='embark_town',  # Categorical variable (embarkation town)
    y='fare',         # Numerical variable (fare)
    data=df,
    palette='viridis' # Color palette
)

plt.title('Fare Distribution by Embarkation Port', fontsize=16)
plt.xlabel('Embarkation Port', fontsize=12)
plt.ylabel('Fare', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\2215541098.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 61.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 13.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# #### 5.12 Point Plot

# %%
# Point plot
sns.catplot (x='pclass', y='fare', hue='embarked', kind='point', data=df)

# %% [markdown]
# #### 5.13 LM Plot

# %%
# to check relation of two variables
# lm plot
sns.lmplot (x="fare", y="age", data=df)

# %%
# a scatter plot with a regression line, showing how fare and age relate for passengers who paid less than 300

# Filter the dataset where fare is less than 300
df_filtered = df[df['fare'] < 300]

# Draw the LM plot
sns.lmplot(data=df_filtered, x="age", y="fare", hue="sex", aspect=1.5)

# Show the plot
plt.title("LM Plot of Age vs Fare (Fare < 300)")
plt.show()

# %%
# lm plot after removal of outliers

# Filter dataset for fare < 300
df_filtered = df[df["fare"] < 300]

# Function to remove outliers using IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile
    Q3 = df[column].quantile(0.75)  # Third quartile
    IQR = Q3 - Q1  # Interquartile range
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers for age and fare
df_filtered = remove_outliers(df_filtered, "age")
df_filtered = remove_outliers(df_filtered, "fare")

# Plot LM plot
sns.lmplot(data=df_filtered, x="age", y="fare", hue="sex", aspect=1.5)

# Show the plot
plt.title("LM Plot of Age vs Fare (Fare < 300, Outliers Removed)")
plt.show()

# %% [markdown]
# ### 6. Grouping in the Data

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df['age_groups']= pd.cut (df['age'], [0,10,18,30,50,80], labels= ['kids', 'teens', 'youth', 'mid_age', 'old_age'])

# %%
df.head ()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone age_gruops age_groups
# 0    man        True  Southampton    no  False      youth      youth
# 1  woman       False    Cherbourg   yes  False    mid_age    mid_age
# 2  woman       False  Southampton   yes   True      youth      youth
# 3  woman       False  Southampton   yes  False    mid_age    mid_age
# 4    man        True  Southampton    no   True    mid_age    mid_age

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_gruops', 'age_groups'],
#       dtype='object')

# %%
df.groupby ("age_groups")["survived"].mean ().plot (kind = "bar")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\4238318534.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby ("age_groups")["survived"].mean ().plot (kind = "bar")
# <Axes: xlabel='age_groups'>

# %% [markdown]
# #### 6.1 Survival Age Group on Titanic

# %%
import matplotlib.pyplot as plt

# Create the bar plot
ax = df.groupby("age_groups")["survived"].mean().plot(kind="bar", figsize=(8,6))

# Add exact data values on top of each bar
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2,  # X position (center of bar)
            p.get_height(),  # Y position (top of bar)
            f'{p.get_height():.2f}',  # Value label (formatted to 2 decimal places)
            ha='center',  # Align center
            va='bottom',  # Position slightly above the bar
            fontsize=12, 
            color='black')

# Improve plot readability
plt.xlabel("Age Groups")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Age Groups on Titanic")
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\3347600644.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ax = df.groupby("age_groups")["survived"].mean().plot(kind="bar", figsize=(8,6))

# %% [markdown]
# #### 6.2 Fare by Age Group on Titanic

# %%
import matplotlib.pyplot as plt

# Create the bar plot
ax = df.groupby("age_groups")["fare"].mean().plot(kind="bar", figsize=(8,6))

# Add exact data values on top of each bar
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2,  # X position (center of bar)
            p.get_height(),  # Y position (top of bar)
            f'{p.get_height():.2f}',  # Value label (formatted to 2 decimal places)
            ha='center',  # Align center
            va='bottom',  # Position slightly above the bar
            fontsize=12, 
            color='black')

# Improve plot readability
plt.xlabel("Age Groups")
plt.ylabel("Fare")
plt.title("Fare by Age Groups on Titanic")
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5852\3898903542.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ax = df.groupby("age_groups")["fare"].mean().plot(kind="bar", figsize=(8,6))

# %% [markdown]
# #### 6.3 Survived by Family Size on Titanic

# %%
import pandas as pd

# Load the Titanic dataset (assuming df is already loaded)
# df = pd.read_csv("titanic.csv")  # Uncomment if loading from a file

# Create the family_size column
df["family_size"] = df["sibsp"] + df["parch"] + 1  # +1 to include the passenger themselves

# Display first few rows
print(df[["sibsp", "parch", "family_size"]].head())
# Out:
#    sibsp  parch  family_size
# 0      1      0            2
# 1      1      0            2
# 2      0      0            1
# 3      1      0            2
# 4      0      0            1

# %%
df.head ()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone age_gruops age_groups  \
# 0    man        True  Southampton    no  False      youth      youth
# 1  woman       False    Cherbourg   yes  False    mid_age    mid_age
# 2  woman       False  Southampton   yes   True      youth      youth
# 3  woman       False  Southampton   yes  False    mid_age    mid_age
# 4    man        True  Southampton    no   True    mid_age    mid_age
#
#    family_size
# 0            2
# 1            2
# 2            1
# 3            2
# 4            1

# %%
df = df.drop("age_gruops", axis=1)  # axis=1 means dropping a column

# %%
df.head ()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone age_groups  family_size
# 0    man        True  Southampton    no  False      youth            2
# 1  woman       False    Cherbourg   yes  False    mid_age            2
# 2  woman       False  Southampton   yes   True      youth            1
# 3  woman       False  Southampton   yes  False    mid_age            2
# 4    man        True  Southampton    no   True    mid_age            1

# %%
import matplotlib.pyplot as plt

# Create the bar plot
ax = df.groupby("family_size")["survived"].mean().plot(kind="bar", figsize=(10,6))

# Add exact data values on top of each bar
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2,  # X position (center of bar)
            p.get_height(),  # Y position (top of bar)
            f'{p.get_height():.2f}',  # Value label (formatted to 2 decimal places)
            ha='center',  # Align center
            va='bottom',  # Position slightly above the bar
            fontsize=12, 
            color='black')

# Improve plot readability
plt.xlabel("Family Size")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Family Size on Titanic")
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.show()

# %% [markdown]
# Summary of Findings: Survival Rate by Family Size on Titanic
# The analysis of survival rates based on family size in the Titanic dataset reveals key insights into how family dynamics influenced survival outcomes. The data suggests a clear relationship between family size and survival probability.
#
# Small Families Had Higher Survival Rates:
#
# Passengers traveling with one or two family members (family size 2-3) had the highest survival rates.
# This suggests that smaller families had a better chance of staying together and accessing lifeboats.
# Solo Travelers Faced Lower Survival Chances:
#
# Individuals traveling alone (family size 1) had a significantly lower survival rate.
# This may indicate difficulty in securing a spot on lifeboats without family support.
# Larger Families Had Reduced Survival Rates:
#
# Families with four or more members showed a decline in survival rates.
# This could be due to logistical challenges in evacuating together or prioritization of smaller groups during rescue efforts.
# Conclusion:
# The findings highlight the impact of family structure on survival, with small family groups benefiting the most. The lower survival rate for solo travelers and large families indicates that social connections played a crucial role in survival decisions during the disaster.
